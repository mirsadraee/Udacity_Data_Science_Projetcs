# %%
import sys
# import libraries
import re

import numpy as np
import pandas as pd

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('punkt')
nltk.download('wordnet')

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.multioutput import MultiOutputClassifier

from sqlalchemy import create_engine

import pickle
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/alirezamirsadraee/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/alirezamirsadraee/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def load_data(database_filepath):
    engine = create_engine('sqlite:///' + database_filepath)
    df = pd.read_sql_table('ETL_Pipeline', engine)
    X = df['message']
    Y = df[df.columns[4:]]
    category_names = Y.columns
    return X, Y, category_names

def tokenize(text):
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens


def build_model():
    pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(RandomForestClassifier()))
    ])
    
    parameters = {
    'clf__estimator__n_estimators': [2],
    'clf__estimator__min_samples_split': [2],
    }

    # create grid search object
    model = GridSearchCV(pipeline, param_grid=parameters,verbose = 2, cv = 3)
    
    return model

def evaluate_model(model, X_test, Y_test, category_names):
    Y_pred = model.predict(X_test)
    
    for i in range(36):
        print(classification_report(Y_test.iloc[:,i], Y_pred[:,i])) #, target_names=category_names))


def save_model(model, model_filepath):
    with open(model_filepath, 'wb') as file:
        pickle.dump(model, file)

# %%
# def main():
# if len(sys.argv) == 3:
# database_filepath, model_filepath = sys.argv[1:]
database_filepath = '../data/ETL_Pipeline.db'
model_filepath = 'ML_Classifier.pkl'
print('Loading data...\n    DATABASE: {}'.format(database_filepath))
# Out:
# Loading data...
#     DATABASE: ../data/ETL_Pipeline.db

# %%
X, Y, category_names = load_data(database_filepath)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
print('Reading ' + database_filepath)
print('Reading ' + model_filepath)
print(category_names  )
# Out:
# Reading ../data/ETL_Pipeline.db
# Reading ML_Classifier.pkl
# Index(['('related',)', '('request',)', '('offer',)', '('aid_related',)',
#        '('medical_help',)', '('medical_products',)', '('search_and_rescue',)',
#        '('security',)', '('military',)', '('child_alone',)', '('water',)',
#        '('food',)', '('shelter',)', '('clothing',)', '('money',)',
#        '('missing_people',)', '('refugees',)', '('death',)', '('other_aid',)',
#        '('infrastructure_related',)', '('transport',)', '('buildings',)',
#        '('electricity',)', '('tools',)', '('hospitals',)', '('shops',)',
#        '('aid_centers',)', '('other_infrastructure',)', '('weather_related',)',
#        '('floods',)', '('storm',)', '('fire',)', '('earthquake',)',
#        '('cold',)', '('other_weather',)', '('direct_report',)'],
#       dtype='object')

# %%
print('Building model...')
model = build_model()
print(model)
# Out:
# Building model...
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x29013a050>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier()))]),
#              param_grid={'clf__estimator__min_samples_split': [2],
#                          'clf__estimator__n_estimators': [2]},
#              verbose=2)

# %%
print('Training model...')
model.fit(X_train, Y_train)
# Out:
# Training model...
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END clf__estimator__min_samples_split=2, clf__estimator__n_estimators=2; total time=   8.6s
# [CV] END clf__estimator__min_samples_split=2, clf__estimator__n_estimators=2; total time=   8.5s
# [CV] END clf__estimator__min_samples_split=2, clf__estimator__n_estimators=2; total time=   8.5s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x29013a050>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier()))]),
#              param_grid={'clf__estimator__min_samples_split': [2],
#                          'clf__estimator__n_estimators': [2]},
#              verbose=2)

# %%
model.best_score_
# Out:
# 0.19116039035678203

# %%
model.best_params_
best_model = model.best_estimator_
print(best_model)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x29013a050>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier(n_estimators=2)))])

# %%
print('Evaluating model...')
evaluate_model(model, X_test, Y_test, category_names)
# Out:
# Evaluating model...
#               precision    recall  f1-score   support
#
#            0       0.40      0.60      0.48      1175
#            1       0.86      0.74      0.80      4038
#            2       0.80      0.13      0.22        31
#
#     accuracy                           0.71      5244
#    macro avg       0.69      0.49      0.50      5244
# weighted avg       0.76      0.71      0.72      5244
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.91      4330
#            1       0.70      0.23      0.35       914
#
#     accuracy                           0.85      5244
#    macro avg       0.78      0.61      0.63      5244
# weighted avg       0.83      0.85      0.82      5244
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5219
#            1       0.00      0.00      0.00        25
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.89      0.75      3007
#            1       0.70      0.35      0.47      2237
#
#     accuracy                           0.66      5244
#    macro avg       0.68      0.62      0.61      5244
# weighted avg       0.67      0.66      0.63      5244
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96      4810
#            1       0.48      0.06      0.11       434
#
#     accuracy                           0.92      5244
#    macro avg       0.70      0.53      0.53      5244
# weighted avg       0.88      0.92      0.89      5244
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4954
#            1       0.53      0.07      0.12       290
#
#     accuracy                           0.95      5244
#    macro avg       0.74      0.53      0.54      5244
# weighted avg       0.92      0.95      0.92      5244
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      5097
#            1       0.47      0.05      0.10       147
#
#     accuracy                           0.97      5244
#    macro avg       0.72      0.53      0.54      5244
# weighted avg       0.96      0.97      0.96      5244
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5161
#            1       0.00      0.00      0.00        83
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.97      0.98      0.98      5244
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5080
#            1       0.44      0.07      0.13       164
#
#     accuracy                           0.97      5244
#    macro avg       0.71      0.54      0.55      5244
# weighted avg       0.95      0.97      0.96      5244
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5244
#
#     accuracy                           1.00      5244
#    macro avg       1.00      1.00      1.00      5244
# weighted avg       1.00      1.00      1.00      5244
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      4883
#            1       0.60      0.13      0.22       361
#
#     accuracy                           0.93      5244
#    macro avg       0.77      0.56      0.59      5244
# weighted avg       0.92      0.93      0.91      5244
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      4634
#            1       0.67      0.20      0.30       610
#
#     accuracy                           0.90      5244
#    macro avg       0.78      0.59      0.62      5244
# weighted avg       0.88      0.90      0.87      5244
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      4748
#            1       0.66      0.15      0.24       496
#
#     accuracy                           0.91      5244
#    macro avg       0.79      0.57      0.60      5244
# weighted avg       0.89      0.91      0.89      5244
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5150
#            1       0.45      0.05      0.10        94
#
#     accuracy                           0.98      5244
#    macro avg       0.72      0.53      0.54      5244
# weighted avg       0.97      0.98      0.97      5244
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5116
#            1       0.00      0.00      0.00       128
#
#     accuracy                           0.97      5244
#    macro avg       0.49      0.50      0.49      5244
# weighted avg       0.95      0.97      0.96      5244
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5182
#            1       1.00      0.02      0.03        62
#
#     accuracy                           0.99      5244
#    macro avg       0.99      0.51      0.51      5244
# weighted avg       0.99      0.99      0.98      5244
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5040
#            1       0.36      0.02      0.05       204
#
#     accuracy                           0.96      5244
#    macro avg       0.66      0.51      0.51      5244
# weighted avg       0.94      0.96      0.94      5244
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5014
#            1       0.43      0.04      0.07       230
#
#     accuracy                           0.96      5244
#    macro avg       0.69      0.52      0.52      5244
# weighted avg       0.93      0.96      0.94      5244
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      4539
#            1       0.33      0.05      0.08       705
#
#     accuracy                           0.86      5244
#    macro avg       0.60      0.52      0.50      5244
# weighted avg       0.80      0.86      0.81      5244
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4933
#            1       0.30      0.03      0.05       311
#
#     accuracy                           0.94      5244
#    macro avg       0.62      0.51      0.51      5244
# weighted avg       0.90      0.94      0.91      5244
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      5005
#            1       0.41      0.08      0.13       239
#
#     accuracy                           0.95      5244
#    macro avg       0.69      0.54      0.55      5244
# weighted avg       0.93      0.95      0.94      5244
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4980
#            1       0.42      0.06      0.11       264
#
#     accuracy                           0.95      5244
#    macro avg       0.69      0.53      0.54      5244
# weighted avg       0.93      0.95      0.93      5244
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5136
#            1       0.12      0.01      0.02       108
#
#     accuracy                           0.98      5244
#    macro avg       0.55      0.50      0.50      5244
# weighted avg       0.96      0.98      0.97      5244
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5212
#            1       0.00      0.00      0.00        32
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5194
#            1       0.33      0.02      0.04        50
#
#     accuracy                           0.99      5244
#    macro avg       0.66      0.51      0.52      5244
# weighted avg       0.98      0.99      0.99      5244
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5218
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5188
#            1       0.00      0.00      0.00        56
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5031
#            1       0.05      0.00      0.01       213
#
#     accuracy                           0.96      5244
#    macro avg       0.51      0.50      0.49      5244
# weighted avg       0.92      0.96      0.94      5244
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.87      3794
#            1       0.74      0.35      0.47      1450
#
#     accuracy                           0.79      5244
#    macro avg       0.77      0.65      0.67      5244
# weighted avg       0.78      0.79      0.76      5244
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      4800
#            1       0.79      0.23      0.36       444
#
#     accuracy                           0.93      5244
#    macro avg       0.86      0.61      0.66      5244
# weighted avg       0.92      0.93      0.91      5244
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      4749
#            1       0.65      0.18      0.29       495
#
#     accuracy                           0.91      5244
#    macro avg       0.79      0.59      0.62      5244
# weighted avg       0.90      0.91      0.89      5244
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5191
#            1       0.00      0.00      0.00        53
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      4771
#            1       0.76      0.32      0.45       473
#
#     accuracy                           0.93      5244
#    macro avg       0.85      0.65      0.71      5244
# weighted avg       0.92      0.93      0.92      5244
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5134
#            1       0.27      0.03      0.05       110
#
#     accuracy                           0.98      5244
#    macro avg       0.63      0.51      0.52      5244
# weighted avg       0.96      0.98      0.97      5244
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4995
#            1       0.19      0.03      0.05       249
#
#     accuracy                           0.95      5244
#    macro avg       0.57      0.51      0.51      5244
# weighted avg       0.92      0.95      0.93      5244
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90      4200
#            1       0.68      0.19      0.30      1044
#
#     accuracy                           0.82      5244
#    macro avg       0.75      0.58      0.60      5244
# weighted avg       0.80      0.82      0.78      5244
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print('Saving model...\n    MODEL: {}'.format(model_filepath))
save_model(model, model_filepath)

print('Trained model saved!')

    # else:
    #     print('Please provide the filepath of the disaster messages database '\
    #           'as the first argument and the filepath of the pickle file to '\
    #           'save the model to as the second argument. \n\nExample: python '\
    #           'train_classifier.py ../data/DisasterResponse.db classifier.pkl')


# if __name__ == '__main__':

#     main()
# Out:
# Saving model...
#     MODEL: ML_Classifier.pkl
# Trained model saved!

# %%
Y_pred = model.predict(X_test)
evaluate_model(model, X_test, Y_test, category_names)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.60      0.48      1175
#            1       0.86      0.74      0.80      4038
#            2       0.80      0.13      0.22        31
#
#     accuracy                           0.71      5244
#    macro avg       0.69      0.49      0.50      5244
# weighted avg       0.76      0.71      0.72      5244
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.91      4330
#            1       0.70      0.23      0.35       914
#
#     accuracy                           0.85      5244
#    macro avg       0.78      0.61      0.63      5244
# weighted avg       0.83      0.85      0.82      5244
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5219
#            1       0.00      0.00      0.00        25
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.89      0.75      3007
#            1       0.70      0.35      0.47      2237
#
#     accuracy                           0.66      5244
#    macro avg       0.68      0.62      0.61      5244
# weighted avg       0.67      0.66      0.63      5244
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96      4810
#            1       0.48      0.06      0.11       434
#
#     accuracy                           0.92      5244
#    macro avg       0.70      0.53      0.53      5244
# weighted avg       0.88      0.92      0.89      5244
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4954
#            1       0.53      0.07      0.12       290
#
#     accuracy                           0.95      5244
#    macro avg       0.74      0.53      0.54      5244
# weighted avg       0.92      0.95      0.92      5244
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      5097
#            1       0.47      0.05      0.10       147
#
#     accuracy                           0.97      5244
#    macro avg       0.72      0.53      0.54      5244
# weighted avg       0.96      0.97      0.96      5244
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5161
#            1       0.00      0.00      0.00        83
#
#     accuracy                           0.98      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.97      0.98      0.98      5244
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      5080
#            1       0.44      0.07      0.13       164
#
#     accuracy                           0.97      5244
#    macro avg       0.71      0.54      0.55      5244
# weighted avg       0.95      0.97      0.96      5244
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5244
#
#     accuracy                           1.00      5244
#    macro avg       1.00      1.00      1.00      5244
# weighted avg       1.00      1.00      1.00      5244
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      4883
#            1       0.60      0.13      0.22       361
#
#     accuracy                           0.93      5244
#    macro avg       0.77      0.56      0.59      5244
# weighted avg       0.92      0.93      0.91      5244
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      4634
#            1       0.67      0.20      0.30       610
#
#     accuracy                           0.90      5244
#    macro avg       0.78      0.59      0.62      5244
# weighted avg       0.88      0.90      0.87      5244
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      4748
#            1       0.66      0.15      0.24       496
#
#     accuracy                           0.91      5244
#    macro avg       0.79      0.57      0.60      5244
# weighted avg       0.89      0.91      0.89      5244
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5150
#            1       0.45      0.05      0.10        94
#
#     accuracy                           0.98      5244
#    macro avg       0.72      0.53      0.54      5244
# weighted avg       0.97      0.98      0.97      5244
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5116
#            1       0.00      0.00      0.00       128
#
#     accuracy                           0.97      5244
#    macro avg       0.49      0.50      0.49      5244
# weighted avg       0.95      0.97      0.96      5244
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5182
#            1       1.00      0.02      0.03        62
#
#     accuracy                           0.99      5244
#    macro avg       0.99      0.51      0.51      5244
# weighted avg       0.99      0.99      0.98      5244
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5040
#            1       0.36      0.02      0.05       204
#
#     accuracy                           0.96      5244
#    macro avg       0.66      0.51      0.51      5244
# weighted avg       0.94      0.96      0.94      5244
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5014
#            1       0.43      0.04      0.07       230
#
#     accuracy                           0.96      5244
#    macro avg       0.69      0.52      0.52      5244
# weighted avg       0.93      0.96      0.94      5244
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      4539
#            1       0.33      0.05      0.08       705
#
#     accuracy                           0.86      5244
#    macro avg       0.60      0.52      0.50      5244
# weighted avg       0.80      0.86      0.81      5244
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4933
#            1       0.30      0.03      0.05       311
#
#     accuracy                           0.94      5244
#    macro avg       0.62      0.51      0.51      5244
# weighted avg       0.90      0.94      0.91      5244
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      5005
#            1       0.41      0.08      0.13       239
#
#     accuracy                           0.95      5244
#    macro avg       0.69      0.54      0.55      5244
# weighted avg       0.93      0.95      0.94      5244
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      4980
#            1       0.42      0.06      0.11       264
#
#     accuracy                           0.95      5244
#    macro avg       0.69      0.53      0.54      5244
# weighted avg       0.93      0.95      0.93      5244
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5136
#            1       0.12      0.01      0.02       108
#
#     accuracy                           0.98      5244
#    macro avg       0.55      0.50      0.50      5244
# weighted avg       0.96      0.98      0.97      5244
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5212
#            1       0.00      0.00      0.00        32
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5194
#            1       0.33      0.02      0.04        50
#
#     accuracy                           0.99      5244
#    macro avg       0.66      0.51      0.52      5244
# weighted avg       0.98      0.99      0.99      5244
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5218
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.99      5244
#    macro avg       0.50      0.50      0.50      5244
# weighted avg       0.99      0.99      0.99      5244
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5188
#            1       0.00      0.00      0.00        56
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      5031
#            1       0.05      0.00      0.01       213
#
#     accuracy                           0.96      5244
#    macro avg       0.51      0.50      0.49      5244
# weighted avg       0.92      0.96      0.94      5244
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.87      3794
#            1       0.74      0.35      0.47      1450
#
#     accuracy                           0.79      5244
#    macro avg       0.77      0.65      0.67      5244
# weighted avg       0.78      0.79      0.76      5244
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      4800
#            1       0.79      0.23      0.36       444
#
#     accuracy                           0.93      5244
#    macro avg       0.86      0.61      0.66      5244
# weighted avg       0.92      0.93      0.91      5244
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      4749
#            1       0.65      0.18      0.29       495
#
#     accuracy                           0.91      5244
#    macro avg       0.79      0.59      0.62      5244
# weighted avg       0.90      0.91      0.89      5244
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      5191
#            1       0.00      0.00      0.00        53
#
#     accuracy                           0.99      5244
#    macro avg       0.49      0.50      0.50      5244
# weighted avg       0.98      0.99      0.98      5244
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      4771
#            1       0.76      0.32      0.45       473
#
#     accuracy                           0.93      5244
#    macro avg       0.85      0.65      0.71      5244
# weighted avg       0.92      0.93      0.92      5244
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      5134
#            1       0.27      0.03      0.05       110
#
#     accuracy                           0.98      5244
#    macro avg       0.63      0.51      0.52      5244
# weighted avg       0.96      0.98      0.97      5244
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      4995
#            1       0.19      0.03      0.05       249
#
#     accuracy                           0.95      5244
#    macro avg       0.57      0.51      0.51      5244
# weighted avg       0.92      0.95      0.93      5244
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90      4200
#            1       0.68      0.19      0.30      1044
#
#     accuracy                           0.82      5244
#    macro avg       0.75      0.58      0.60      5244
# weighted avg       0.80      0.82      0.78      5244
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
category_names
# Out:
# Index(['('related',)', '('request',)', '('offer',)', '('aid_related',)',
#        '('medical_help',)', '('medical_products',)', '('search_and_rescue',)',
#        '('security',)', '('military',)', '('child_alone',)', '('water',)',
#        '('food',)', '('shelter',)', '('clothing',)', '('money',)',
#        '('missing_people',)', '('refugees',)', '('death',)', '('other_aid',)',
#        '('infrastructure_related',)', '('transport',)', '('buildings',)',
#        '('electricity',)', '('tools',)', '('hospitals',)', '('shops',)',
#        '('aid_centers',)', '('other_infrastructure',)', '('weather_related',)',
#        '('floods',)', '('storm',)', '('fire',)', '('earthquake',)',
#        '('cold',)', '('other_weather',)', '('direct_report',)'],
#       dtype='object')
